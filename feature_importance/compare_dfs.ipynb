# %%
import pandas as pd
import numpy as np
from scipy import stats

def compare_clusters(df1, df2):
    """Compare feature distributions between two cluster dataframes."""
    
    # Exclude file_name column if present
    cols_to_compare = [col for col in df1.columns if col != "file_name"]
    
    differences = {}
    for col in cols_to_compare:
        
        # Calculate mean difference
        mean_diff = df1[col].mean() - df2[col].mean()
        
        # T-test to check statistical significance
        t_stat, p_value = stats.ttest_ind(df1[col], df2[col], nan_policy='omit')
        
        differences[col] = {
            "cluster_0_mean": df1[col].mean(),
            "cluster_1_mean": df2[col].mean(),
            "mean_difference": mean_diff,
            "p_value": p_value,
            "significant": p_value < 0.05
        }
    
    return pd.DataFrame(differences).T.sort_values("mean_difference", ascending=False)

if __name__ == "__main__":
    # Load the dataframes
    df1 = pd.read_csv("../visuals/rep_samples/Spectral_Cluster/0/cluster_0.csv")
    df2 = pd.read_csv("../visuals/rep_samples/Spectral_Cluster/1/cluster_1.csv")
    
    # Compare the dataframes
    differences = compare_clusters(df1, df2)
    
    # Print features sorted by biggest differences
    print(differences)
    print("\nMost significant features (p < 0.05):")
    print(differences[differences["significant"]])
# Out:
#                         cluster_0_mean cluster_1_mean mean_difference  \
# a1_spectral_centroid_y     2679.894102    2225.149821      454.744281
# a1_spectral_centroid_x     2679.894102    2225.149821      454.744281
# a0_spectral_centroid_y     2446.049968    2252.620994      193.428974
# a0_spectral_centroid_x     2446.049968    2252.620994      193.428974
# a1_spectral_entropy_x         5.806427       5.373629        0.432799
# ...                                ...            ...             ...
# a0_peaks_per_second_x         3.610205       12.27628       -8.666075
# a1_spectral_bandwidth_x    1094.480789    1163.354607      -68.873818
# a1_spectral_bandwidth_y    1094.480789    1163.354607      -68.873818
# a0_spectral_bandwidth_x    1191.573495    1271.778343      -80.204848
# a0_spectral_bandwidth_y    1191.573495    1271.778343      -80.204848
#
#                           p_value significant
# a1_spectral_centroid_y        0.0        True
# a1_spectral_centroid_x        0.0        True
# a0_spectral_centroid_y   0.001716        True
# a0_spectral_centroid_x   0.001716        True
# a1_spectral_entropy_x         0.0        True
# ...                           ...         ...
# a0_peaks_per_second_x         0.0        True
# a1_spectral_bandwidth_x  0.201266       False
# a1_spectral_bandwidth_y  0.201266       False
# a0_spectral_bandwidth_x   0.10469       False
# a0_spectral_bandwidth_y   0.10469       False
#
# [67 rows x 5 columns]
#
# Most significant features (p < 0.05):
#                                   cluster_0_mean cluster_1_mean  \
# a1_spectral_centroid_y               2679.894102    2225.149821
# a1_spectral_centroid_x               2679.894102    2225.149821
# a0_spectral_centroid_y               2446.049968    2252.620994
# a0_spectral_centroid_x               2446.049968    2252.620994
# a1_spectral_entropy_x                   5.806427       5.373629
# a1_spectral_entropy_y                   5.806427       5.373629
# peak_mag_correlation_y                  0.319352      -0.023465
# peak_mag_correlation_x                  0.319352      -0.023465
# a0_median_time_diff_y                   0.384344       0.091789
# a0_median_time_diff_x                   0.384344       0.091789
# a1_median_time_diff_y                   0.384056       0.094011
# a1_median_time_diff_x                   0.384056       0.094011
# a0_spectral_entropy_y                   5.737423       5.459237
# a0_spectral_entropy_x                   5.737423       5.459237
# a0_mean_time_diff_x                     0.372184       0.094396
# a0_mean_time_diff_y                     0.372184       0.094396
# a1_mean_time_diff_y                     0.372784        0.09677
# a1_mean_time_diff_x                     0.372784        0.09677
# a1_max_peak_y                           0.347035       0.200219
# a1_max_peak_x                           0.347035       0.200219
# a1_median_peak_y                        0.275905        0.12966
# a1_median_peak_x                        0.275905        0.12966
# a1_unused_peak_proportion_x             0.185619       0.039418
# a1_unused_peak_proportion_y             0.185619       0.039418
# a0_median_peak_y                        0.234494       0.131856
# a0_median_peak_x                        0.234494       0.131856
# a0_max_peak_y                           0.285249         0.2018
# a0_max_peak_x                           0.285249         0.2018
# a1_std_dev_time_diff_x                  0.052361       0.027308
# a1_std_dev_time_diff_y                  0.052361       0.027308
# avg_peak_mag_diff_y                     0.055728       0.031503
# avg_peak_mag_diff_x                     0.055728       0.031503
# a0_std_dev_time_diff_y                  0.047324       0.025416
# a0_std_dev_time_diff_x                  0.047324       0.025416
# a1_std_peak_x                           0.043958        0.02246
# a1_std_peak_y                           0.043958        0.02246
# a0_spectral_flatness_x                  0.256554       0.237529
# a0_spectral_flatness_y                  0.256554       0.237529
# a0_percent_time_above_threshold_x       0.001976       0.004082
# a0_percent_time_above_threshold_y       0.001976       0.004082
# a1_percent_time_above_threshold_y       0.002092       0.004403
# a1_percent_time_above_threshold_x       0.002092       0.004403
# cluster_spectral                             0.0            1.0
# a1_num_boilings_y                       1.144928       2.822222
# a1_num_boilings_x                       1.144928       2.822222
# a0_num_boilings_y                       1.115942       2.833333
# a0_num_boilings_x                       1.115942       2.833333
# num_peak_mag_high_diff_y                0.666667       2.911111
# num_peak_mag_high_diff_x                0.666667       2.911111
# a1_peaks_per_second_y                    3.58146       12.06694
# a1_peaks_per_second_x                    3.58146       12.06694
# a0_peaks_per_second_y                   3.610205       12.27628
# a0_peaks_per_second_x                   3.610205       12.27628
#
#                                   mean_difference   p_value significant
# a1_spectral_centroid_y                 454.744281       0.0        True
# a1_spectral_centroid_x                 454.744281       0.0        True
# a0_spectral_centroid_y                 193.428974  0.001716        True
# a0_spectral_centroid_x                 193.428974  0.001716        True
# a1_spectral_entropy_x                    0.432799       0.0        True
# a1_spectral_entropy_y                    0.432799       0.0        True
# peak_mag_correlation_y                   0.342817       0.0        True
# peak_mag_correlation_x                   0.342817       0.0        True
# a0_median_time_diff_y                    0.292555       0.0        True
# a0_median_time_diff_x                    0.292555       0.0        True
# a1_median_time_diff_y                    0.290045       0.0        True
# a1_median_time_diff_x                    0.290045       0.0        True
# a0_spectral_entropy_y                    0.278185  0.000002        True
# a0_spectral_entropy_x                    0.278185  0.000002        True
# a0_mean_time_diff_x                      0.277788       0.0        True
# a0_mean_time_diff_y                      0.277788       0.0        True
# a1_mean_time_diff_y                      0.276015       0.0        True
# a1_mean_time_diff_x                      0.276015       0.0        True
# a1_max_peak_y                            0.146816       0.0        True
# a1_max_peak_x                            0.146816       0.0        True
# a1_median_peak_y                         0.146245       0.0        True
# a1_median_peak_x                         0.146245       0.0        True
# a1_unused_peak_proportion_x              0.146201   0.00007        True
# a1_unused_peak_proportion_y              0.146201   0.00007        True
# a0_median_peak_y                         0.102638       0.0        True
# a0_median_peak_x                         0.102638       0.0        True
# a0_max_peak_y                            0.083449  0.000005        True
# a0_max_peak_x                            0.083449  0.000005        True
# a1_std_dev_time_diff_x                   0.025053  0.000962        True
# a1_std_dev_time_diff_y                   0.025053  0.000962        True
# avg_peak_mag_diff_y                      0.024225  0.000001        True
# avg_peak_mag_diff_x                      0.024225  0.000001        True
# a0_std_dev_time_diff_y                   0.021908  0.001234        True
# a0_std_dev_time_diff_x                   0.021908  0.001234        True
# a1_std_peak_x                            0.021498       0.0        True
# a1_std_peak_y                            0.021498       0.0        True
# a0_spectral_flatness_x                   0.019025  0.025011        True
# a0_spectral_flatness_y                   0.019025  0.025011        True
# a0_percent_time_above_threshold_x       -0.002105  0.000153        True
# a0_percent_time_above_threshold_y       -0.002105  0.000153        True
# a1_percent_time_above_threshold_y       -0.002311  0.000327        True
# a1_percent_time_above_threshold_x       -0.002311  0.000327        True
# cluster_spectral                             -1.0       0.0        True
# a1_num_boilings_y                       -1.677295       0.0        True
# a1_num_boilings_x                       -1.677295       0.0        True
# a0_num_boilings_y                       -1.717391       0.0        True
# a0_num_boilings_x                       -1.717391       0.0        True
# num_peak_mag_high_diff_y                -2.244444  0.000015        True
# num_peak_mag_high_diff_x                -2.244444  0.000015        True
# a1_peaks_per_second_y                    -8.48548       0.0        True
# a1_peaks_per_second_x                    -8.48548       0.0        True
# a0_peaks_per_second_y                   -8.666075       0.0        True
# a0_peaks_per_second_x                   -8.666075       0.0        True
# c:\Users\ellio\AppData\Local\Programs\Python\Python312\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
