# %%
from scipy.io import loadmat
import pandas as pd
import numpy as np

# %%
mat = loadmat("C:/Users/HELIOS-300/Desktop/MATLAB/NasaDataCapstone/data/MATLAB/MATLAB 1-02 PM Mon, Mar 11, 2024 Run4 .mat")
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'UntitledPXI1Slot2_ai0_Time', 'UntitledPXI1Slot2_ai0', 'UntitledPXI1Slot2_ai1_Time', 'UntitledPXI1Slot2_ai1'])

# %%
t0 = mat["UntitledPXI1Slot2_ai0_Time"].squeeze()
x0 = mat["UntitledPXI1Slot2_ai0"].squeeze()

t1 = mat["UntitledPXI1Slot2_ai1_Time"].squeeze()
x1 = mat["UntitledPXI1Slot2_ai1"].squeeze()

# %%
mat_df = pd.DataFrame({
    "time": t0,
    "ai0": x0,
    "ai1": x1,
})

mat_df.head()
# Out:
#      time       ai0       ai1
# 0  0.0000 -0.001007 -0.001326
# 1  0.0001 -0.000441  0.000731
# 2  0.0002  0.004065  0.002266
# 3  0.0003  0.009683  0.002803
# 4  0.0004  0.012107  0.004786
